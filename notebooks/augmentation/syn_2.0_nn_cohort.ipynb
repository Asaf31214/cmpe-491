# %%
import random
from os import path

import numpy as np
import polars as pl
import torch
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score,
    roc_curve,
)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch import nn, optim
from torch.utils.data import DataLoader, TensorDataset

# %%
SEED = 491
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if cuda else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda:0

# %%
data_path = "../../data/previous"
syn_cohort = path.join(data_path, "synthetic_patients_2.0_cohort.csv")
processed_seer = path.join(data_path, "processed_seer_with_age.csv")
syn_cohort_dataset = pl.read_csv(syn_cohort)
seer_dataset = pl.read_csv(processed_seer)

# %%
label_col = "target"

X_seer = syn_cohort_dataset.select(pl.exclude(label_col)).to_numpy().astype(np.float32)
y_seer = syn_cohort_dataset.get_column(label_col).to_numpy().astype(np.int64).ravel()
X_train, X_val, y_train, y_val = train_test_split(X_seer, y_seer, test_size=0.2, stratify=y_seer, random_state=491)

X_test = seer_dataset.select(pl.exclude(label_col)).to_numpy().astype(np.float32)
y_test = seer_dataset.get_column(label_col).to_numpy().astype(np.int64).ravel()

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train).astype(np.float32)
X_val = scaler.transform(X_val).astype(np.float32)
X_test = scaler.transform(X_test).astype(np.float32)

# %%
X_train_t = torch.from_numpy(X_train).to(device)
y_train_t = torch.from_numpy(y_train).to(device)
X_val_t = torch.from_numpy(X_val).to(device)
y_val_t = torch.from_numpy(y_val).to(device)
X_test_t = torch.from_numpy(X_test).to(device)
y_test_t = torch.from_numpy(y_test).to(device)

g = torch.Generator()
g.manual_seed(SEED)
train_loader = DataLoader(TensorDataset(X_train_t, y_train_t), batch_size=64, shuffle=True, generator=g)
val_loader = DataLoader(TensorDataset(X_val_t, y_val_t), batch_size=64, shuffle=False)
test_loader = DataLoader(TensorDataset(X_test_t, y_test_t), batch_size=64, shuffle=False)

# %%
n_features = X_train.shape[1]
n_classes = int(np.unique(y_seer).size)
print(f"n_features: {n_features}\nn_classes: {n_classes}")
# Out:
# n_features: 6
# n_classes: 2

# %%
torch.backends.cuda.matmul.fp32_precision = "ieee"


class BinaryMLP(nn.Module):
    def __init__(self, in_dim):
        super().__init__()
        self.mlp = nn.Sequential(
            nn.Linear(in_dim, 512),
            nn.ReLU(),
            nn.Dropout(0.2),

            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.2),

            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.1),

            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.1),

            nn.Linear(64, 1),
        )

    def forward(self, x):
        return self.mlp(x).squeeze(1)


model = torch.compile(BinaryMLP(n_features).to(device))
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
def optimal_threshold(y_true, probs):
    fpr, tpr, thresholds = roc_curve(y_true, probs)
    j_scores = tpr - fpr
    return thresholds[np.argmax(j_scores)]

# %%
def eval_metrics(loader, name="Validation"):
    model.eval()
    all_logits, all_targets = [], []
    with torch.no_grad():
        for x_batch, y_batch in loader:
            logits_v = model(x_batch)
            all_logits.append(torch.sigmoid(logits_v).cpu())
            all_targets.append(y_batch.cpu())

    y_prob = torch.cat(all_logits).numpy()
    y_true = torch.cat(all_targets).numpy()

    auc = roc_auc_score(y_true, y_prob)
    threshold = optimal_threshold(y_true, y_prob)
    print(f"Optimal threshold for {name}: {threshold:.3f}")

    y_pred = (y_prob >= threshold).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    acc = accuracy_score(y_true, y_pred)
    sens = recall_score(y_true, y_pred, zero_division=0)
    spec = tn / (tn + fp) if (tn + fp) else 0
    prec = precision_score(y_true, y_pred, zero_division=0)
    npv = tn / (tn + fn) if (tn + fn) else 0
    f1 = f1_score(y_true, y_pred, zero_division=0)

    print(f"\n{name} metrics:")
    print(f"Accuracy              : {acc:.4f}")
    print(f"Sensitivity (Recall)  : {sens:.4f}")
    print(f"Specificity           : {spec:.4f}")
    print(f"Precision (PPV)       : {prec:.4f}")
    print(f"NPV                   : {npv:.4f}")
    print(f"F1 Score              : {f1:.4f}")
    print(f"AUC                   : {auc:.4f}")

    return {
        "Accuracy": acc,
        "Sensitivity": sens,
        "Specificity": spec,
        "Precision": prec,
        "NPV": npv,
        "F1": f1,
        "AUC": auc,
    }

# %%
EPOCHS = 20

pos_weight = torch.tensor([len(y_train) / np.sum(y_train) - 1], dtype=torch.float32).to(device)
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

for epoch in range(EPOCHS):
    print(f"\nEpoch {epoch}")
    model.train()
    for batch_x_t, batch_y_t in train_loader:
        optimizer.zero_grad(set_to_none=True)
        logits = model(batch_x_t)
        loss = criterion(logits, batch_y_t.float())
        loss.backward()
        optimizer.step()

    eval_metrics(val_loader, name="Validation")

print("\n" + "-" * 50)
print("Final metrics:")
val_metrics = eval_metrics(val_loader, name="Validation")
test_metrics = eval_metrics(test_loader, name=f"Test (cohort)")
# Out:
# Epoch 0
# Optimal threshold for Validation: 0.510
#
# Validation metrics:
# Accuracy              : 0.6185
# Sensitivity (Recall)  : 0.5669
# Specificity           : 0.6710
# Precision (PPV)       : 0.6370
# NPV                   : 0.6034
# F1 Score              : 0.5999
# AUC                   : 0.6506
#
# Epoch 1
# Optimal threshold for Validation: 0.443
#
# Validation metrics:
# Accuracy              : 0.6075
# Sensitivity (Recall)  : 0.6026
# Specificity           : 0.6125
# Precision (PPV)       : 0.6129
# NPV                   : 0.6022
# F1 Score              : 0.6077
# AUC                   : 0.6453
#
# Epoch 2
# Optimal threshold for Validation: 0.459
#
# Validation metrics:
# Accuracy              : 0.6030
# Sensitivity (Recall)  : 0.6472
# Specificity           : 0.5580
# Precision (PPV)       : 0.5985
# NPV                   : 0.6084
# F1 Score              : 0.6219
# AUC                   : 0.6428
#
# Epoch 3
# Optimal threshold for Validation: 0.488
#
# Validation metrics:
# Accuracy              : 0.6080
# Sensitivity (Recall)  : 0.6581
# Specificity           : 0.5570
# Precision (PPV)       : 0.6020
# NPV                   : 0.6154
# F1 Score              : 0.6288
# AUC                   : 0.6472
#
# Epoch 4
# Optimal threshold for Validation: 0.506
#
# Validation metrics:
# Accuracy              : 0.6130
# Sensitivity (Recall)  : 0.5867
# Specificity           : 0.6398
# Precision (PPV)       : 0.6238
# NPV                   : 0.6032
# F1 Score              : 0.6047
# AUC                   : 0.6499
#
# Epoch 5
# Optimal threshold for Validation: 0.503
#
# Validation metrics:
# Accuracy              : 0.6065
# Sensitivity (Recall)  : 0.5788
# Specificity           : 0.6347
# Precision (PPV)       : 0.6173
# NPV                   : 0.5968
# F1 Score              : 0.5974
# AUC                   : 0.6451
#
# Epoch 6
# Optimal threshold for Validation: 0.498
#
# Validation metrics:
# Accuracy              : 0.6065
# Sensitivity (Recall)  : 0.6046
# Specificity           : 0.6085
# Precision (PPV)       : 0.6112
# NPV                   : 0.6018
# F1 Score              : 0.6079
# AUC                   : 0.6461
#
# Epoch 7
# Optimal threshold for Validation: 0.519
#
# Validation metrics:
# Accuracy              : 0.6075
# Sensitivity (Recall)  : 0.5837
# Specificity           : 0.6317
# Precision (PPV)       : 0.6174
# NPV                   : 0.5985
# F1 Score              : 0.6001
# AUC                   : 0.6472
#
# Epoch 8
# Optimal threshold for Validation: 0.483
#
# Validation metrics:
# Accuracy              : 0.6110
# Sensitivity (Recall)  : 0.6293
# Specificity           : 0.5923
# Precision (PPV)       : 0.6112
# NPV                   : 0.6108
# F1 Score              : 0.6201
# AUC                   : 0.6466
#
# Epoch 9
# Optimal threshold for Validation: 0.470
#
# Validation metrics:
# Accuracy              : 0.6095
# Sensitivity (Recall)  : 0.6402
# Specificity           : 0.5782
# Precision (PPV)       : 0.6071
# NPV                   : 0.6122
# F1 Score              : 0.6233
# AUC                   : 0.6433
#
# Epoch 10
# Optimal threshold for Validation: 0.496
#
# Validation metrics:
# Accuracy              : 0.6105
# Sensitivity (Recall)  : 0.5510
# Specificity           : 0.6710
# Precision (PPV)       : 0.6304
# NPV                   : 0.5948
# F1 Score              : 0.5880
# AUC                   : 0.6470
#
# Epoch 11
# Optimal threshold for Validation: 0.548
#
# Validation metrics:
# Accuracy              : 0.6095
# Sensitivity (Recall)  : 0.4886
# Specificity           : 0.7326
# Precision (PPV)       : 0.6504
# NPV                   : 0.5845
# F1 Score              : 0.5580
# AUC                   : 0.6450
#
# Epoch 12
# Optimal threshold for Validation: 0.470
#
# Validation metrics:
# Accuracy              : 0.6050
# Sensitivity (Recall)  : 0.6214
# Specificity           : 0.5883
# Precision (PPV)       : 0.6058
# NPV                   : 0.6041
# F1 Score              : 0.6135
# AUC                   : 0.6397
#
# Epoch 13
# Optimal threshold for Validation: 0.473
#
# Validation metrics:
# Accuracy              : 0.5975
# Sensitivity (Recall)  : 0.6442
# Specificity           : 0.5499
# Precision (PPV)       : 0.5931
# NPV                   : 0.6029
# F1 Score              : 0.6176
# AUC                   : 0.6373
#
# Epoch 14
# Optimal threshold for Validation: 0.506
#
# Validation metrics:
# Accuracy              : 0.6065
# Sensitivity (Recall)  : 0.6145
# Specificity           : 0.5984
# Precision (PPV)       : 0.6090
# NPV                   : 0.6039
# F1 Score              : 0.6117
# AUC                   : 0.6403
#
# Epoch 15
# Optimal threshold for Validation: 0.498
#
# Validation metrics:
# Accuracy              : 0.5925
# Sensitivity (Recall)  : 0.5699
# Specificity           : 0.6155
# Precision (PPV)       : 0.6015
# NPV                   : 0.5843
# F1 Score              : 0.5852
# AUC                   : 0.6306
#
# Epoch 16
# Optimal threshold for Validation: 0.497
#
# Validation metrics:
# Accuracy              : 0.6105
# Sensitivity (Recall)  : 0.6363
# Specificity           : 0.5843
# Precision (PPV)       : 0.6091
# NPV                   : 0.6121
# F1 Score              : 0.6224
# AUC                   : 0.6445
#
# Epoch 17
# Optimal threshold for Validation: 0.540
#
# Validation metrics:
# Accuracy              : 0.6030
# Sensitivity (Recall)  : 0.5193
# Specificity           : 0.6882
# Precision (PPV)       : 0.6291
# NPV                   : 0.5844
# F1 Score              : 0.5689
# AUC                   : 0.6391
#
# Epoch 18
# Optimal threshold for Validation: 0.481
#
# Validation metrics:
# Accuracy              : 0.6030
# Sensitivity (Recall)  : 0.6125
# Specificity           : 0.5933
# Precision (PPV)       : 0.6053
# NPV                   : 0.6006
# F1 Score              : 0.6089
# AUC                   : 0.6401
#
# Epoch 19
# Optimal threshold for Validation: 0.502
#
# Validation metrics:
# Accuracy              : 0.6035
# Sensitivity (Recall)  : 0.6105
# Specificity           : 0.5964
# Precision (PPV)       : 0.6063
# NPV                   : 0.6006
# F1 Score              : 0.6084
# AUC                   : 0.6381
#
# --------------------------------------------------
# Final metrics:
# Optimal threshold for Validation: 0.502
#
# Validation metrics:
# Accuracy              : 0.6035
# Sensitivity (Recall)  : 0.6105
# Specificity           : 0.5964
# Precision (PPV)       : 0.6063
# NPV                   : 0.6006
# F1 Score              : 0.6084
# AUC                   : 0.6381
# Optimal threshold for Test (cohort): 0.922
#
# Test (cohort) metrics:
# Accuracy              : 0.7755
# Sensitivity (Recall)  : 0.6151
# Specificity           : 0.7880
# Precision (PPV)       : 0.1836
# NPV                   : 0.9635
# F1 Score              : 0.2827
# AUC                   : 0.7611
