# %%
import random
from os import path

import numpy as np
import polars as pl
import torch
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score,
    roc_curve,
)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch import nn, optim
from torch.utils.data import DataLoader, TensorDataset

# %%
SEED = 491
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if cuda else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda:0

# %%
data_path = "../../data/previous"
syn_seer = path.join(data_path, "synthetic_patients_2.0_seer.csv")
processed_cohort = path.join(data_path, "processed_cohort_with_age.csv")
syn_seer_dataset = pl.read_csv(syn_seer)
cohort_dataset = pl.read_csv(processed_cohort)

# %%
label_col = "target"

X_seer = syn_seer_dataset.select(pl.exclude(label_col)).to_numpy().astype(np.float32)
y_seer = syn_seer_dataset.get_column(label_col).to_numpy().astype(np.int64).ravel()
X_train, X_val, y_train, y_val = train_test_split(X_seer, y_seer, test_size=0.2, stratify=y_seer, random_state=491)

X_test = cohort_dataset.select(pl.exclude(label_col)).to_numpy().astype(np.float32)
y_test = cohort_dataset.get_column(label_col).to_numpy().astype(np.int64).ravel()

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train).astype(np.float32)
X_val = scaler.transform(X_val).astype(np.float32)
X_test = scaler.transform(X_test).astype(np.float32)

# %%
X_train_t = torch.from_numpy(X_train).to(device)
y_train_t = torch.from_numpy(y_train).to(device)
X_val_t = torch.from_numpy(X_val).to(device)
y_val_t = torch.from_numpy(y_val).to(device)
X_test_t = torch.from_numpy(X_test).to(device)
y_test_t = torch.from_numpy(y_test).to(device)

g = torch.Generator()
g.manual_seed(SEED)
train_loader = DataLoader(TensorDataset(X_train_t, y_train_t), batch_size=64, shuffle=True, generator=g)
val_loader = DataLoader(TensorDataset(X_val_t, y_val_t), batch_size=64, shuffle=False)
test_loader = DataLoader(TensorDataset(X_test_t, y_test_t), batch_size=64, shuffle=False)

# %%
n_features = X_train.shape[1]
n_classes = int(np.unique(y_seer).size)
print(f"n_features: {n_features}\nn_classes: {n_classes}")
# Out:
# n_features: 6
# n_classes: 2

# %%
torch.backends.cuda.matmul.fp32_precision = "ieee"


class BinaryMLP(nn.Module):
    def __init__(self, in_dim):
        super().__init__()
        self.mlp = nn.Sequential(
            nn.Linear(in_dim, 512),
            nn.ReLU(),
            nn.Dropout(0.2),

            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.2),

            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.1),

            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.1),

            nn.Linear(64, 1),
        )

    def forward(self, x):
        return self.mlp(x).squeeze(1)


model = torch.compile(BinaryMLP(n_features).to(device))
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
def optimal_threshold(y_true, probs):
    fpr, tpr, thresholds = roc_curve(y_true, probs)
    j_scores = tpr - fpr
    return thresholds[np.argmax(j_scores)]

# %%
def eval_metrics(loader, name="Validation"):
    model.eval()
    all_logits, all_targets = [], []
    with torch.no_grad():
        for x_batch, y_batch in loader:
            logits_v = model(x_batch)
            all_logits.append(torch.sigmoid(logits_v).cpu())
            all_targets.append(y_batch.cpu())

    y_prob = torch.cat(all_logits).numpy()
    y_true = torch.cat(all_targets).numpy()

    auc = roc_auc_score(y_true, y_prob)
    threshold = optimal_threshold(y_true, y_prob)
    print(f"Optimal threshold for {name}: {threshold:.3f}")

    y_pred = (y_prob >= threshold).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    acc = accuracy_score(y_true, y_pred)
    sens = recall_score(y_true, y_pred, zero_division=0)
    spec = tn / (tn + fp) if (tn + fp) else 0
    prec = precision_score(y_true, y_pred, zero_division=0)
    npv = tn / (tn + fn) if (tn + fn) else 0
    f1 = f1_score(y_true, y_pred, zero_division=0)

    print(f"\n{name} metrics:")
    print(f"Accuracy              : {acc:.4f}")
    print(f"Sensitivity (Recall)  : {sens:.4f}")
    print(f"Specificity           : {spec:.4f}")
    print(f"Precision (PPV)       : {prec:.4f}")
    print(f"NPV                   : {npv:.4f}")
    print(f"F1 Score              : {f1:.4f}")
    print(f"AUC                   : {auc:.4f}")

    return {
        "Accuracy": acc,
        "Sensitivity": sens,
        "Specificity": spec,
        "Precision": prec,
        "NPV": npv,
        "F1": f1,
        "AUC": auc,
    }

# %%
EPOCHS = 20

pos_weight = torch.tensor([len(y_train) / np.sum(y_train) - 1], dtype=torch.float32).to(device)
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

for epoch in range(EPOCHS):
    print(f"\nEpoch {epoch}")
    model.train()
    for batch_x_t, batch_y_t in train_loader:
        optimizer.zero_grad(set_to_none=True)
        logits = model(batch_x_t)
        loss = criterion(logits, batch_y_t.float())
        loss.backward()
        optimizer.step()

    eval_metrics(val_loader, name="Validation")

print("\n" + "-" * 50)
print("Final metrics:")
val_metrics = eval_metrics(val_loader, name="Validation")
test_metrics = eval_metrics(test_loader, name=f"Test (cohort)")
# Out:
# Epoch 0
# Optimal threshold for Validation: 0.499
#
# Validation metrics:
# Accuracy              : 0.5915
# Sensitivity (Recall)  : 0.6395
# Specificity           : 0.5442
# Precision (PPV)       : 0.5804
# NPV                   : 0.6049
# F1 Score              : 0.6085
# AUC                   : 0.6136
#
# Epoch 1
# Optimal threshold for Validation: 0.455
#
# Validation metrics:
# Accuracy              : 0.5970
# Sensitivity (Recall)  : 0.6062
# Specificity           : 0.5879
# Precision (PPV)       : 0.5919
# NPV                   : 0.6022
# F1 Score              : 0.5990
# AUC                   : 0.6140
#
# Epoch 2
# Optimal threshold for Validation: 0.520
#
# Validation metrics:
# Accuracy              : 0.6020
# Sensitivity (Recall)  : 0.4814
# Specificity           : 0.7210
# Precision (PPV)       : 0.6298
# NPV                   : 0.5850
# F1 Score              : 0.5457
# AUC                   : 0.6199
#
# Epoch 3
# Optimal threshold for Validation: 0.539
#
# Validation metrics:
# Accuracy              : 0.6000
# Sensitivity (Recall)  : 0.4834
# Specificity           : 0.7150
# Precision (PPV)       : 0.6258
# NPV                   : 0.5839
# F1 Score              : 0.5455
# AUC                   : 0.6178
#
# Epoch 4
# Optimal threshold for Validation: 0.499
#
# Validation metrics:
# Accuracy              : 0.5980
# Sensitivity (Recall)  : 0.5690
# Specificity           : 0.6266
# Precision (PPV)       : 0.6004
# NPV                   : 0.5958
# F1 Score              : 0.5843
# AUC                   : 0.6201
#
# Epoch 5
# Optimal threshold for Validation: 0.495
#
# Validation metrics:
# Accuracy              : 0.5970
# Sensitivity (Recall)  : 0.5710
# Specificity           : 0.6226
# Precision (PPV)       : 0.5987
# NPV                   : 0.5954
# F1 Score              : 0.5845
# AUC                   : 0.6180
#
# Epoch 6
# Optimal threshold for Validation: 0.497
#
# Validation metrics:
# Accuracy              : 0.5935
# Sensitivity (Recall)  : 0.6123
# Specificity           : 0.5750
# Precision (PPV)       : 0.5869
# NPV                   : 0.6006
# F1 Score              : 0.5993
# AUC                   : 0.6166
#
# Epoch 7
# Optimal threshold for Validation: 0.574
#
# Validation metrics:
# Accuracy              : 0.5910
# Sensitivity (Recall)  : 0.4139
# Specificity           : 0.7656
# Precision (PPV)       : 0.6352
# NPV                   : 0.5698
# F1 Score              : 0.5012
# AUC                   : 0.6160
#
# Epoch 8
# Optimal threshold for Validation: 0.490
#
# Validation metrics:
# Accuracy              : 0.5945
# Sensitivity (Recall)  : 0.5217
# Specificity           : 0.6663
# Precision (PPV)       : 0.6066
# NPV                   : 0.5855
# F1 Score              : 0.5609
# AUC                   : 0.6162
#
# Epoch 9
# Optimal threshold for Validation: 0.511
#
# Validation metrics:
# Accuracy              : 0.5885
# Sensitivity (Recall)  : 0.5498
# Specificity           : 0.6266
# Precision (PPV)       : 0.5922
# NPV                   : 0.5853
# F1 Score              : 0.5702
# AUC                   : 0.6122
#
# Epoch 10
# Optimal threshold for Validation: 0.490
#
# Validation metrics:
# Accuracy              : 0.5945
# Sensitivity (Recall)  : 0.5680
# Specificity           : 0.6207
# Precision (PPV)       : 0.5962
# NPV                   : 0.5930
# F1 Score              : 0.5817
# AUC                   : 0.6158
#
# Epoch 11
# Optimal threshold for Validation: 0.552
#
# Validation metrics:
# Accuracy              : 0.6000
# Sensitivity (Recall)  : 0.4340
# Specificity           : 0.7637
# Precision (PPV)       : 0.6442
# NPV                   : 0.5778
# F1 Score              : 0.5187
# AUC                   : 0.6167
#
# Epoch 12
# Optimal threshold for Validation: 0.552
#
# Validation metrics:
# Accuracy              : 0.5950
# Sensitivity (Recall)  : 0.4491
# Specificity           : 0.7388
# Precision (PPV)       : 0.6291
# NPV                   : 0.5763
# F1 Score              : 0.5241
# AUC                   : 0.6141
#
# Epoch 13
# Optimal threshold for Validation: 0.503
#
# Validation metrics:
# Accuracy              : 0.5915
# Sensitivity (Recall)  : 0.6083
# Specificity           : 0.5750
# Precision (PPV)       : 0.5853
# NPV                   : 0.5981
# F1 Score              : 0.5965
# AUC                   : 0.6106
#
# Epoch 14
# Optimal threshold for Validation: 0.545
#
# Validation metrics:
# Accuracy              : 0.5830
# Sensitivity (Recall)  : 0.5448
# Specificity           : 0.6207
# Precision (PPV)       : 0.5861
# NPV                   : 0.5803
# F1 Score              : 0.5647
# AUC                   : 0.6079
#
# Epoch 15
# Optimal threshold for Validation: 0.522
#
# Validation metrics:
# Accuracy              : 0.5915
# Sensitivity (Recall)  : 0.5287
# Specificity           : 0.6534
# Precision (PPV)       : 0.6007
# NPV                   : 0.5844
# F1 Score              : 0.5624
# AUC                   : 0.6103
#
# Epoch 16
# Optimal threshold for Validation: 0.508
#
# Validation metrics:
# Accuracy              : 0.5850
# Sensitivity (Recall)  : 0.5821
# Specificity           : 0.5879
# Precision (PPV)       : 0.5821
# NPV                   : 0.5879
# F1 Score              : 0.5821
# AUC                   : 0.6097
#
# Epoch 17
# Optimal threshold for Validation: 0.490
#
# Validation metrics:
# Accuracy              : 0.5900
# Sensitivity (Recall)  : 0.6495
# Specificity           : 0.5313
# Precision (PPV)       : 0.5774
# NPV                   : 0.6059
# F1 Score              : 0.6114
# AUC                   : 0.6111
#
# Epoch 18
# Optimal threshold for Validation: 0.499
#
# Validation metrics:
# Accuracy              : 0.5860
# Sensitivity (Recall)  : 0.5247
# Specificity           : 0.6465
# Precision (PPV)       : 0.5941
# NPV                   : 0.5797
# F1 Score              : 0.5572
# AUC                   : 0.6079
#
# Epoch 19
# Optimal threshold for Validation: 0.517
#
# Validation metrics:
# Accuracy              : 0.5860
# Sensitivity (Recall)  : 0.6173
# Specificity           : 0.5551
# Precision (PPV)       : 0.5778
# NPV                   : 0.5953
# F1 Score              : 0.5969
# AUC                   : 0.6081
#
# --------------------------------------------------
# Final metrics:
# Optimal threshold for Validation: 0.517
#
# Validation metrics:
# Accuracy              : 0.5860
# Sensitivity (Recall)  : 0.6173
# Specificity           : 0.5551
# Precision (PPV)       : 0.5778
# NPV                   : 0.5953
# F1 Score              : 0.5969
# AUC                   : 0.6081
# Optimal threshold for Test (cohort): 0.620
#
# Test (cohort) metrics:
# Accuracy              : 0.4847
# Sensitivity (Recall)  : 0.7941
# Specificity           : 0.4198
# Precision (PPV)       : 0.2231
# NPV                   : 0.9067
# F1 Score              : 0.3484
# AUC                   : 0.5960
